# %% [markdown]
# ## MLOps Zoomcamp - Homework 2
# The data: NYC Taxi, Jan - Mar 2023, Green Taxis

# %%
from IPython.display import Image

# %% [markdown]
# ### Question 1 - Install MLflow

# %%
Image("img/question_1.png")

# %% [markdown]
# ### Question 2 - Download and preprocess the data

# %%
Image("img/question2_4.png")

# %% [markdown]
# ### Question 3 - Train a model with autolog

# %%
Image("img/question_3.png")

# %% [markdown]
# ### Question 4 - Launch the tracking server locally

# %%
Image("img/question2_4.png")

# %% [markdown]
# ### Question 5 - Tune model hyperparameters

# %%
Image("img/question_5.png")

# %% [markdown]
# ### Question 6 - Promote the best model to the model registry

# %%
Image('img/question_6.png')
